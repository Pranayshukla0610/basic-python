# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/basic-python/blob/main/DSA_PYTHON_ARRAYS_PRACTICE_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Find the Sum of All Elements

arr = list(map(int, input("Enter an array:").split()))

total = 0

for num in arr:
  total += num

print("Sum of All Elements:",total)
# Out:
# Enter an array:2 5 8 9 13 17 78
# Sum of All Elements: 132

# %%
#Find the Average of Array Elements

arr = list(map(int, input("Enter an array:").split()))

total = 0

for num in arr:
  total += num

print("Average of Array Elements:",total/len(arr))
# Out:
# Enter an array:2 5 8 9 13 17 78
# Average of Array Elements: 18.857142857142858

# %%
#Count Even and Odd Numbers

arr = list(map(int, input("Enter an array:").split()))

even = 0
odd = 0

for num in arr:
  if num % 2 == 0:
    even += 1
  else:
    odd += 1

print("Even Numbers:",even)
print("Odd Numbers:",odd)
# Out:
# Enter an array:2 6 18 13 11 15 20 22
# Even Numbers: 5
# Odd Numbers: 3

# %%
#Count Positive, Negative and Zero Elements

arr = list(map(int, input("Enter an array:").split()))

positive = 0
negative = 0
zero = 0

for num in arr:
  if num > 0:
    positive += 1
  elif num < 0:
    negative -= 1
  else:
    zero += 1

print("Positive Numbers:",positive)
print("Negative Numbers:",negative)
print("Zero Numbers:",zero)
# Out:
# Enter an array:4 -14 0 78 -5 -8 -9 32 0
# Positive Numbers: 3
# Negative Numbers: -4
# Zero Numbers: 2

# %%
#Search an Element (Linear Search)

arr = list(map(int, input("Enter an array:").split()))
target = int(input("Enter a target:"))

found = False

for i in range(len(arr)):
  if arr[i] == target:
    found = True
    print("Element Found at Index:",i)
    break

if not found:
  print("Element Not Found")
# Out:
# Enter an array:5 8 9 10 14 4 3
# Enter a target:10
# Element Found at Index: 3

# %%
#Count Frequency of a Given Element

arr = list(map(int, input("Enter an array:").split()))
target = int(input("Enter a target:"))

count = 0

for num in arr:
  if num == target:
    count += 1

print("Frequency of target:",count)
# Out:
# Enter an array:2 4 5 2 8 2 10
# Enter a target:2
# Frequency of target: 3

# %%
#Find First and Last Occurrence

arr = list(map(int, input("Enter an array:").split()))
target = int(input("Enter a target:"))

first = -1
last = -1

for i in range(len(arr)):
  if arr[i] == target:
    if first == -1:
      first = i
    last = i

print("First Occurence:",first)
print("Last Occurence:",last)
# Out:
# Enter an array:1 2 5 8 5 10 5
# Enter a target:5
# First Occurence: 2
# Last Occurence: 6

# %%
#Copy One Array into Another

arr = list(map(int, input("Enter an array").split()))

copy_arr = []

for num in arr:
  copy_arr.append(num)

print("Original Array:",arr)
print("Copied Array:",copy_arr)
# Out:
# Enter an array8 4 6 2 9
# Original Array: [8, 4, 6, 2, 9]
# Copied Array: [8, 4, 6, 2, 9]
