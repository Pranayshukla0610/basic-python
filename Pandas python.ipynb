# %%
import pandas as pd
import numpy as np

# %%
# Pandas call string as an onject
country = ['USA','India','Pakistan','Nepal','Sri Lanka']
pd.Series(country)
# Out:
# 0          USA
# 1        India
# 2     Pakistan
# 3        Nepal
# 4    Sri Lanka
# dtype: object

# %%
# Integers
runs = [13,24,56,36,100]
pd.Series(runs)
# Out:
# 0     13
# 1     24
# 2     56
# 3     36
# 4    100
# dtype: int64

# %%
runs = [13,24,56,36,100]
runs_series = pd.Series(runs)

# %%
# Custom Index
marks = [67,57,87,100]
subjects = ['Maths','English','Science','Hindi']
pd.Series(marks,index=subject)
# Out:
# Maths       67
# English     57
# Science     87
# Hindi      100
# dtype: int64

# %%
marks = [67,57,87,100]
subjects = ['Maths','English','Science','Hindi']
pd.Series(marks,index=subjects,name='Pranay marks')
# Out:
# Maths       67
# English     57
# Science     87
# Hindi      100
# Name: Pranay marks, dtype: int64

# %%
marks = pd.Series(marks,index=subjects,name='Pranay marks')
marks
# Out:
# Maths       67
# English     57
# Science     87
# Hindi      100
# Name: Pranay marks, dtype: int64

# %%
marks = {
    'Maths':67,
    'English':57,
    'Science':89,
    'Hindi':100
}
marks_Series = pd.Series(marks,name='Pranay marks')
marks_Series
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Pranay marks, dtype: int64

# %%
marks_Series.dtype
# Out:
# dtype('int64')

# %%
marks_Series.name
# Out:
# 'Pranay marks'

# %%
# is_unique
marks_Series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
# Index
marks_Series.index
# Out:
# Index(['Maths', 'English', 'Science', 'Hindi'], dtype='object')

# %%
runs_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Values
marks_Series.values
# Out:
# array([ 67,  57,  89, 100], dtype=int64)

# %%
subs = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
type(pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\subs.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
subs = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\subs.csv',squeeze=True)
subs
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_22192\2592618712.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   subs = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\subs.csv',squeeze=True)
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\subs.csv',squeeze=True))
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_22192\2167291365.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   type(pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\subs.csv',squeeze=True))
# pandas.core.series.Series

# %%
data = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\kohli_ipl.csv')
data
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
df = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\kohli_ipl.csv',squeeze=True)
df
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_22192\3837354455.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   df = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\kohli_ipl.csv',squeeze=True)
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
bl = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\bollywood.csv')
bl
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
bl.sample()
# Out:
#         movie    lead
# 851  Phoonk 2  Sudeep

# %%
bl.sample(5)
# Out:
#                                      movie               lead
# 140                                Baazaar       Radhika Apte
# 1005                            Haal-e-Dil       Amita Pathak
# 693                      Yeh Khula Aasmaan         Anya Anand
# 901                                  Kaalo  Aditya Srivastava
# 626   Once Upon ay Time in Mumbai Dobaara!       Akshay Kumar

# %%
bl = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\bollywood.csv')
bl
movies = bl.squeeze()

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
type(pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\bollywood.csv', squeeze=True))
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_22192\376357624.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   type(pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\bollywood.csv', squeeze=True))
# pandas.core.frame.DataFrame

# %%
bl.sample(5)
# Out:
#                 movie          lead
# 1050             Apne    Dharmendra
# 764      Naughty @ 40       Govinda
# 1396     Sheen (film)   Tarun Arora
# 803   Tere Mere Phere  Vinay Pathak
# 565     Badlapur Boys   Annu Kapoor

# %%
# sort values in ASC order
data.sort_values(by='runs')
# Out:
#      match_no  runs
# 86         87     0
# 210       211     0
# 206       207     0
# 205       206     0
# 90         91     0
# ..        ...   ...
# 163       164   100
# 119       120   100
# 122       123   108
# 125       126   109
# 127       128   113
#
# [215 rows x 2 columns]

# %%
data.sort_values(by='runs',ascending=False)
# Out:
#      match_no  runs
# 127       128   113
# 125       126   109
# 122       123   108
# 163       164   100
# 119       120   100
# ..        ...   ...
# 92         93     0
# 210       211     0
# 129       130     0
# 7           8     0
# 134       135     0
#
# [215 rows x 2 columns]

# %%
df.sort_values(by='runs',ascending=False).head(1).values[0]
# Out:
# array([128, 113], dtype=int64)

# %%
df.sort_values(by='match_no',ascending=False).head(1).values[0]
# Out:
# array([215,   7], dtype=int64)

# %%
# sort index
bl
