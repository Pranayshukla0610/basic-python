# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/basic-python/blob/main/Python_Basics_(Brackets).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PARENTHESIS()**

# %%
print("Hello")
len([1,2,3])
# Out:
# Hello
# 3

# %%
result = (5 + 3)*2
print(result)
# Out:
# 16

# %% [markdown]
# Tuples

# %%
t = (1,2,3)
print(t)
# Out:
# (1, 2, 3)

# %%
t = (5,)
print(t)
# Out:
# (5,)

# %%
a, b = (10,20)

# %%
gen = (x*x for x in range(5))

# %%
gen
# Out:
# <generator object <genexpr> at 0x7bb708737100>

# %%
y = 10
square = lambda x:(y*y)
print(square)
# Out:
# <function <lambda> at 0x7bb708706fc0>

# %%
a = [1,2,3,4]

# %%
a[0]
# Out:
# 1

# %%
a[-1]
# Out:
# 4

# %%
a[1:3]
# Out:
# [2, 3]

# %%
a[::2]
# Out:
# [1, 3]

# %%
a[::-1]
# Out:
# [4, 3, 2, 1]

# %%
matrix = [[1,2],[3,4]]

# %%
matrix[0][1]
# Out:
# 2

# %%
a = {1,2,3}
b = {2,3,6}

print(a & b)
# Out:
# {2, 3}

# %%
print(a | b)
# Out:
# {1, 2, 3, 6}

# %%
print(a - b)
# Out:
# {1}
