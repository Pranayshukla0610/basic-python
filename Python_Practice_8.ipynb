# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/basic-python/blob/main/Python_Practice_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Find the Intersection of Two Lists (Without Using Sets)

list1 = list(map(int,input("Enter first list:").split()))
list2 = list(map(int, input("Enter second list:").split()))

result = []

for num in list1:
  if num in list2:
    result.append(num)

print(result)
# Out:
# Enter first list:2 4 7 9 8 6
# Enter second list:2 7 9 1 5 6
# [2, 7, 9, 6]

# %%
#Count Words in a Sentence

sentence = input("Enter a sentence:")

words = sentence.split()
count = 0

for word in words:
  count += 1

print(count)
# Out:
# Enter a sentence:I Love my India
# 4

# %%
sentence = input("Enter a sentence:")

words = sentence.split()

count = {}

for word in words:
    count[word] = count.get(word, 0) + 1

print(count)
# Out:
# Enter a sentence:I love programming language. Python is programming language
# {'I': 1, 'love': 1, 'programming': 2, 'language.': 1, 'Python': 1, 'is': 1, 'language': 1}

# %%
#Check if a Number is a Perfect Number

number = int(input("Enter a number:"))

total = 0

for i in range(1,number):
  if number % i == 0:
    total += i

if total == number:
  print("Perfect number")
else:
  print("Not a Perfect Number")
# Out:
# Enter a number:28
# Perfect number

# %%
#Find the Largest Word in a Paragraph
text = input("Enter a sentence:")

words = text.split()
maximum = ""

for word in words:
  if len(word) > len(maximum):
    maximum = word

print("Largest Word:",maximum)
# Out:
# Enter a sentence:Python programming language is widely used for data science
# Largest Word: programming

# %%
#Find difference between two lists

list1 = list(map(int,input("Enter first list:").split()))
list2 = list(map(int, input("Enter second list:").split()))

result = []

for num in list1:
  if num not in list2:
    result.append(num)

print(result)
# Out:
# Enter first list:2 3 6 8 9
# Enter second list:1 3 6 7 4
# [2, 8, 9]

# %%
#Find the Sum of Digits Until a Single Digit

digit = int(input("Enter a number:"))

while number >= 10:

    total = 0

    while number > 0:
        total += number % 10
        number //= 10

    number = total

print(number)
# Out:
# Enter a number:4875
# 3

# %%
#Find All Leaders in an Array

#A leader is an element greater than all elements to its right.

arr = list(map(int, input("Enter an array").split()))

leaders = []

maximum = float('-inf')

for num in reversed(arr):
  if num > maximum:
    maximum = num
    leaders.append(num)

leaders.reverse()
# Out:
# Enter an array16 17 4 3 5 2
