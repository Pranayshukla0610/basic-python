# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/basic-python/blob/main/DSA_Python_Array_Practice_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Remove Duplicates from a Sorted Array

arr = list(map(int, input("Enter an array:").split()))
arr.sort()
result = [arr[0]]

for i in range(1,len(arr)):
  if arr[i] != arr[i-1]:
    result.append(arr[i])

print("Array after removing duplicates:",result)
# Out:
# Enter an array:1 1 2 2 3 4 4 5
# Array after removing duplicates: [1, 2, 3, 4, 5]

# %%
#Remove All Occurrences of an Element
arr = list(map(int, input("Enter an array:").split()))
target = int(input("Enter a target:"))

result = []

for i in range(len(arr)):
  if arr[i] != target:
    result.append(arr[i])

print("Result after removing all occurences:",result)
# Out:
# Enter an array:1 2 2 1 3 4 4 5 5
# Enter a target:4
# Result after removing all occurences: [1, 2, 2, 1, 3, 5, 5]

# %%
#Find Missing Number (1 to n)

arr = list(map(int, input("Enter an array:").split()))
n = len(arr) + 1

expected_sum = n * (n + 1)//2

actual_sum = sum(arr)

missing_number = expected_sum - actual_sum

print("Missing Number:",missing_number)
# Out:
# Enter an array:1 2 3 5
# Missing Number: 4

# %%
#Find All Pairs with Given Sum

#Input
#1 5 7 -1 5

#6
#Output
#Pairs:
#1 5
#7 -1
#1 5

arr = list(map(int, input("Enter an array:").split()))

target = int(input("Enter a target:"))

pairs = []

for i in range(len(arr)):
  for j in range(i+1,len(arr)):
    if arr[i] + arr[j] == target:
      pairs.append((arr[i],arr[j]))

print("All pairs:",pairs)
# Out:
# Enter an array:1 5 7 -1 5
# Enter a target:6
# All pairs: [(1, 5), (1, 5), (7, -1)]

# %%
#Find Maximum Difference (Larger Element After Smaller)

arr = list(map(int, input("Enter an array:").split()))

minimum = arr[0]
maximum_diff = arr[1] - arr[0]

for i in range(1, len(arr)):
  difference = arr[i] - minimum
  if difference > maximum_diff:
    maximum_diff = difference

  if arr[i] < minimum:
    minimum = arr[i]

print("Maximum Difference:",maximum_diff)
# Out:
# Enter an array:2 3 10 6 4 8 1
# Maximum Difference: 8

# %%
#Equilibrium Index
#Index where left sum equals right sum.
#Input
#1 3 5 2 2
#Output
#Equilibrium Index = 2

arr = list(map(int, input("Enter array: ").split()))

left_sum = 0
right_sum = sum(arr)

for i in range(len(arr)):
  right_sum -= arr[i]
  if left_sum == right_sum:
    print("Equilibrium Index:")
    break

  left_sum += arr[i]

print(i)
# Out:
# Enter array: 1 3 5 2 2
# Equilibrium Index:
# 2

# %%
#Reverse an Array (In-place)
#Input
#1 2 3 4 5
#Output
#Reversed Array: [5, 4, 3, 2, 1]

arr = list(map(int, input("Enter an array:").split()))

l = 0
r = len(arr)-1

while l < r:
  arr[l], arr[r] = arr[r], arr[l]
  l += 1
  r -= 1

print("Reversed Array:",arr)
# Out:
# Enter an array:1 2 3 4 5
# Reversed Array: [5, 4, 3, 2, 1]
