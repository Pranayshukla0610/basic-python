# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/basic-python/blob/main/Float_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#What is float in Python

x = 10.5
print(type(x))
# Out:
# <class 'float'>

# %%
#create a float variable
x = 3.14
y = float(10)
print(x,y)
# Out:
# 3.14 10.0

# %%
#Check whether a number is float or not.
x = 5.0
print(isinstance(x,float))
# Out:
# True

# %%
#Convert integer to float
x = 10
y = float(x)
print(x,y)
# Out:
# 10 10.0

# %%
#Convert string to float.
a = "10.4"
b = float(a)
print(a,b)
# Out:
# 10.4 10.4

# %%
s = "12.34"
f = float(s)
print(f)
# Out:
# 12.34

# %%
x = float(input("Enter a number:"))
print(x)
# Out:
# Enter a number:10
# 10.0

# %%
x = float(input())
print(x)
# Out:
# 20
# 20.0

# %%
a = 5.5
b = 2.0
print(a + b)
print(a - b)
print(a * b)
print(a/b)
# Out:
# 7.5
# 3.5
# 11.0
# 2.75

# %%
print(5.5//2.0)
# Out:
# 2.0

# %%
print(5.5//2)
# Out:
# 2.0

# %%
print(5.5 % 2)
# Out:
# 1.5

# %%
print(2.5 ** 2)
# Out:
# 6.25

# %%
a = 0.1 + 0.2
b = 0.3
print(a == b)
# Out:
# False

# %%
print(0.1 + 0.2)
# Out:
# 0.30000000000000004

# %%
#Correct way to compare floats
import math
print(math.isclose(0.1+0.2,0.3))
# Out:
# True

# %%
#Round a float
print(round(3.143218976,2))
# Out:
# 3.14

# %%
#Round down and up
import math
print(math.floor(3.9))
print(math.ceil(3.8))
# Out:
# 3
# 4

# %%
#Format float to 2 decimal places
x = 3.14159
print(f"{x:.2f}")
# Out:
# 3.14

# %%
#Use Decimal for accurate calculation
from decimal import Decimal

a = Decimal("0.1")
b = Decimal("0.2")
print(a + b)
# Out:
# 0.3

# %%
#Float + int
print(5 + 2.5)
# Out:
# 7.5

# %%
#Square root
import math
print(math.sqrt(16.0))
# Out:
# 4.0

# %%
print(math.sin(math.pi / 2))
# Out:
# 1.0

# %%
print(math.log(10))
# Out:
# 2.302585092994046

# %%
x = float('inf')
print(x)
# Out:
# inf
