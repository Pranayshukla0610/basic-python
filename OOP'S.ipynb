# %%
class Student:
    def __init__(self, name, age, gender):  # data
        self.name = name
        self.age = age
        self.gender = gender               # missing attribute assignment

    def show_details(self):                # method
        print(f"Name: {self.name}, Age: {self.age}, Gender: {self.gender}")  # corrected variable

student1 = Student("Amit", 23, "Male")
student2 = Student("Sakshi", 24, "Female")
student3 = Student("Apurv", 25, "Male")

# call the method
student1.show_details()
student2.show_details()
student3.show_details()
# Out:
# Name: Amit, Age: 23, Gender: Male
# Name: Sakshi, Age: 24, Gender: Female
# Name: Apurv, Age: 25, Gender: Male

# %%
#Full working version of a samsung cart
#Add item to the cart
#View the total
#Checkout

class Item:
    def __init__(self, name, price):
        self.name = name
        self.price = price

# %%
#Create a Python script to build an ATM that allows a user to:
#Check Balance
#Deposit Money
#Withdraw Money

class ATM:
    def __init__(self,owner,balance):
        self.owner = owner
        self.balance = balance
        

    def check_balance(self):
        print(f"{self.owner}, your current balance is{self.balance}")

    def deposit(self,amount):
        self.balance = self.balance+amount
        print(f"Rs.{amount} deposited. New balance is Rs.{self.balance}")

    def withdraw(self,amount):
        if amount > self.balance:
            print('Not Enough Balance')
        else:
            self.balance = self.balance - amount
            print(f"Rs.{amount}withdrawn. New balance is Rs.{self.balance}")

my_account = ATM("Pranay",500000)
my_account.check_balance()        
my_account.deposit(50000)
my_account.withdraw(12500)
my_account.check_balance()
# Out:
# Pranay, your current balance is500000
# Rs.50000 deposited. New balance is Rs.550000
# Rs.12500withdrawn. New balance is Rs.537500
# Pranay, your current balance is537500

# %%
#Update the above part with PIN Verification
#Create a Python script to build an ATM that allows a user to:
#Verify PIN
#Check Balance
#Deposit Money
#Withdraw Money

class ATM:
    
    def __init__(self,owner,pin,balance=0):
        self.owner = owner
        self.balance= balance
        self.pin=pin
        
    def verify_pin(self,input_pin):
        return self.pin == input_pin
   
        
    def check_balance(self):
        print(f"{self.owner}, your current balance is {self.balance}")
        
    def deposit(self, amount):
        self.balance = self.balance + amount                                    #10000
        print(f" Rs.{amount} deposited. New Balance is Rs.{self.balance}")
        
    def withdraw(self,amount):
        if amount > self.balance:
            print("Not enogh balance")
        else:
            self.balance = self.balance - amount
            print(f" Rs.{amount} withdrawn. New balance is Rs.{self.balance}")
            

my_account = ATM("Samraat","1234",50000)


print("===== Welcome to the ATM=====")

input_pin = input("Please enter your 4-digit PIN:")

if my_account.verify_pin(input_pin):
    
    while True:
        
        print("\n Choose an option to proceed:")
        print("1. Check Balance")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Exit")
        
        choice = input("Enter your choice (1/2/3/4):")
        
        if choice == "1":
            my_account.check_balance()
            
        elif choice == "2":
            amount = int(input("Enter amount to deposit:"))
            my_account.deposit(amount)
            
        elif choice == "3":
            amount= int(input("Enter amount to withdraw:"))
            my_account.withdraw(amount)
            
        elif choice == "4":
            print("Thank you for using the ATM. Have a good day !!")
            break
            
        else:
            print("Invalid Option. Please try again")
            
            
else:
    print("Wrong PIN ! Access Denied")
# Out:
# ===== Welcome to the ATM=====
# Please enter your 4-digit PIN: 1234
#  Choose an option to proceed:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice (1/2/3/4): 1
# Samraat, your current balance is 50000
#
#  Choose an option to proceed:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice (1/2/3/4): 1
# Samraat, your current balance is 50000
#
#  Choose an option to proceed:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice (1/2/3/4): 2
# Enter amount to deposit: 500000
#  Rs.500000 deposited. New Balance is Rs.550000
#
#  Choose an option to proceed:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice (1/2/3/4): 30000
# Invalid Option. Please try again
#
#  Choose an option to proceed:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice (1/2/3/4): 4
# Thank you for using the ATM. Have a good day !!
