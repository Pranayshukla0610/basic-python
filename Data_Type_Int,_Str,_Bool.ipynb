# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/basic-python/blob/main/Data_Type_Int%2C_Str%2C_Bool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 256
b = 256
print(a is b)
# Out:
# True

# %%
print(True == 1)
print(False == 0)
print(True+True+False)
print(isinstance(True,int))
# Out:
# True
# True
# 2
# True

# %%
print(0.1+0.2==0.3)
# Out:
# False

# %%
a = "python"
b = "python"
c = "".join(["py","thon"])

print(a is b)
print(a is c)
# Out:
# True
# False

# %%
c = "".join(["py","thon"])
c
# Out:
# 'python'

# %%
print(0.1+0.2)
# Out:
# 0.30000000000000004

# %%
s = "hello"
s[0] = "H"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2714651402.py in <cell line: 0>()
#       1 s = "hello"
# ----> 2 s[0] = "H"
#
# TypeError: 'str' object does not support item assignment

# %%
s = s.replace("h","H",1)
print(s)
# Out:
# Hello

# %%
a = 10
b = 10.0
print(a == b)
print(a is b)
# Out:
# True
# False

# %%
a = 10
b = 10.0
print(a == b)
# Out:
# True

# %%
values = [0, 0.0, "", " ", [], [1], None, False, True]
for v in values:
  print(v, bool(v))
# Out:
# 0 False
# 0.0 False
#  False
#   True
# [] False
# [1] True
# None False
# False False
# True True

# %%
print("a" > "A")
# Out:
# True

# %%
x = float('inf')
y = float('-inf')
z = float('nan')

print(x > 100000)
print(y < -100000)
print(z == z)
# Out:
# True
# True
# False

# %%
def func():
  print("Function called")
  return True

print(False and func())
print(True or func())
# Out:
# False
# True

# %%
a = 10**100
b = a+1
print(type(a),a==b)
# Out:
# <class 'int'> False

# %%
print(True+True+False)
print(True * 10)
# Out:
# 2
# 10

# %%
a = 5
b = 3
print(a & b)
print(a | b)
print(a ^ b)
# Out:
# 1
# 7
# 6

# %%
print(0.1 + 0.2 == 0.3)
print(0.1 + 0.2)
# Out:
# False
# 0.30000000000000004

# %%
import math
a = 0.1 + 0.2
print(math.isclose(a,0.3))
# Out:
# True

# %%
print(int(3.9))
print(round(3.9))
print(round(3.5))
# Out:
# 3
# 4
# 4

# %%
print("Hello\nWorld")
print("Hello\tWorld")
# Out:
# Hello
# World
# Hello	World

# %%
print("Hello\nWorld")
print(r"Hello\nWorld")
# Out:
# Hello
# World
# Hello\nWorld

# %%
print(isinstance(True, int))
print(isinstance(5, object))
print(isinstance("hello", object))
# Out:
# True
# True
# True
